# %% [markdown]
# # PhaseDependenceExperiment on ibm_kawasaki

# %% [markdown]
# Experiment date: Oct 18 2021
# https://github.com/yiiyama/qc_random/blob/fe1c535d0ff712ce301e61c51ede213daabd1b92/pulse_experiments/phi_dependence/phi_dependence_experiment.py

# %%
import numpy as np
from qiskit import IBMQ
from phi_dependence_experiment import PhaseDependenceExperiment
from qiskit_experiments.database_service import DbExperimentDataV1 as DbExperimentData
from qiskit_experiments.framework import ExperimentData

# %%
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q-utokyo', group='internal', project='icepp')
backend = provider.get_backend('ibm_kawasaki')

# %%
exp = PhaseDependenceExperiment(list(range(backend.configuration().n_qubits)), np.linspace(-np.pi, np.pi, 20))
exp_data = ExperimentData(experiment=exp, backend=backend, job_ids=['616cc77afc34472933045527', '616cc77eab11302ead04749e'])
exp.run_analysis(exp_data)
# Out:
# /home/iiyama/qc_random/pulse_experiments/phi_dependence/phi_dependence_experiment.py:41: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1, 1)
